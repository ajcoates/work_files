# %%
import pandas as pd
import numpy as np
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df1 = pd.DataFrame(pd.read_csv('sf_duplicates.csv'))
db1 = pd.DataFrame(pd.read_csv('salesforce_data.csv'))

# %%
df1.loc[df1['project_id'] == 'AVCPoABgAAA']
# Out:
#   Opportunity: Opportunity ID         stage market_division market_area  \
# 0             0060y00001BJfCT  Closed - Won             NaN         NaN
#
#          market           ae_name       new_business  \
# 0  Inside Sales  Scott Schoenberg  Existing Business
#
#                      account  \
# 0  Vita Coco/All Market Inc.
#
#                                          opportunity   project_id  \
# 0  MMP-31480_VitaCoco_Tampa_Houston-Inside Sales-...  AVCPoABgAAA
#
#           form_date opportunity_created_date opportunity_closed_date  \
# 0  3/4/2020 1:43 PM                12/6/2019               1/24/2020
#
#    gross_expected_revenue  gross_amount  form_created_on_closed_opp  \
# 0                147840.0      147840.0                           1
#
#   market_type
# 0         NaN

# %%
df1.market = df1.market.astype(str)

df4 = df1

str_list = df4.market

a = str_list
b = a.to_list()

c = [x[:-2] for x in b]
d = [x[-2:] for x in b]

f = ['iHeart Media - '+ i + ', ' + j for i, j in zip(c, d)]

df5 = pd.DataFrame({"formatted_market": f})

df5.loc[(df5['formatted_market'] == 'iHeart Media - Inside Sal, es'),'formatted_market'] = 'iHeart Media - Inside Sales'
df5.loc[(df5['formatted_market'] == 'iHeart Media - WestPalmBeach, FL'), 'formatted_market'] = 'iHeart Media - West Palm Beach, FL'
df5.loc[(df5['formatted_market'] == 'iHeart Media - CorpusChristi, TX'), 'formatted_market'] = 'iHeart Media - Corpus Christi, TX'
df5.loc[(df5['formatted_market'] == 'iHeart Media - SanAntonio, TX'), 'formatted_market'] = 'iHeart Media - San Antonio, TX'
df5.loc[(df5['formatted_market'] == 'iHeart Media - ElPaso, TX'), 'formatted_market'] = 'iHeart Media - El Paso, TX'
df5.loc[(df5['formatted_market'] == 'iHeart Media - NewHaven, CT'), 'formatted_market'] = 'iHeart Media - New Haven, CT'
df5.loc[(df5['formatted_market'] == 'iHeart Media - FortMyers, FL'), 'formatted_market'] = 'iHeart Media - Fort Myers/Naples, FL'
df5.loc[(df5['formatted_market'] == 'iHeart Media - SiouxCity, IA'), 'formatted_market'] = 'iHeart Media - Sioux City, IA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - iHeart Media - SaltLakeCity, UT'), 'formatted_market'] = 'iHeart Media - Salt Lake City, UT'
df5.loc[(df5['formatted_market'] == 'iHeart Media - MyrtleBeach, SC'), 'formatted_market'] = 'iHeart Media - Myrtle Beach, SC'
df5.loc[(df5['formatted_market'] == 'iHeart Media - FortCollins, CO'), 'formatted_market'] = 'iHeart Media - Fort Collins, CO'
df5.loc[(df5['formatted_market'] == 'iHeart Media - LosAngeles, CA'), 'formatted_market'] = 'iHeart Media - Los Angeles, CA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - ColoradoSprings, CO'), 'formatted_market'] = 'iHeart Media - Colorado Springs, CO'
df5.loc[(df5['formatted_market'] == 'iHeart Media - NewOrleans, LA'), 'formatted_market'] = 'iHeart Media - New Orleans, LA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - BatonRouge, LA'), 'formatted_market'] = 'iHeart Media - Baton Rouge, LA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - GrandForks, ND'), 'formatted_market'] = 'iHeart Media - El Paso, TX'
df5.loc[(df5['formatted_market'] == 'iHeart Media - LasVegas, NV'), 'formatted_market'] = 'iHeart Media - Las Vegas, NV'
df5.loc[(df5['formatted_market'] == 'iHeart Media - CedarRapids, IA'), 'formatted_market'] = 'iHeart Media - Cedar Rapids/Iowa City, IA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - CapeCod, MA'), 'formatted_market'] = 'iHeart Media - Cape Cod, MA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - FortSmith, AR'), 'formatted_market'] = 'iHeart Media - Fort Smith, AR'
df5.loc[(df5['formatted_market'] == 'iHeart Media - GrandRapids, MI'), 'formatted_market'] = 'iHeart Media - Grand Rapids, AR'
df5.loc[(df5['formatted_market'] == 'iHeart Media - DesMoines, IA'), 'formatted_market'] = 'iHeart Media - Des Moines, IA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - SaintLouis, MO'), 'formatted_market'] = 'iHeart Media - Saint Louis, MO'
df5.loc[(df5['formatted_market'] == 'iHeart Media - BayArea, CA'), 'formatted_market'] = 'iHeart Media - San Francisco, CA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - PanamaCity, FL'), 'formatted_market'] = 'iHeart Media - Panama City/Tallahassee, FL'
df5.loc[(df5['formatted_market'] == 'iHeart Media - OklahomaCity, OK'), 'formatted_market'] = 'iHeart Media - Oklahoma City, OK'
df5.loc[(df5['formatted_market'] == 'iHeart Media - n, an'), 'formatted_market'] = 'iHeart Media - National Sales'
df5.loc[(df5['formatted_market'] == 'iHeart Media - EauClaire, WI'), 'formatted_market'] = 'iHeart Media - Eau Claire, WI'
df5.loc[(df5['formatted_market'] == 'iHeart Media - SanDiego, CA'), 'formatted_market'] = 'iHeart Media - San Diego, CA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - LittleRock, AR'), 'formatted_market'] = 'iHeart Media - Little Rock, AR'
df5.loc[(df5['formatted_market'] == 'iHeart Media - El Paso, TX'), 'formatted_market'] = 'iHeart Media - El Paso, TX'
df5.loc[(df5['formatted_market'] == 'iHeart Media - Roanoke, VA'), 'formatted_market'] = 'iHeart Media - Roanoke/Lynchburg, VA'
df5.loc[(df5['formatted_market'] == 'iHeart Media - Sarasota, FL'), 'formatted_market'] = 'iHeart Media - Sarasota/Bradenton, FL'
df5.loc[(df5['formatted_market'] == 'iHeart Media - Ashland, OH'),'formatted_market'] = 'iHeart Media - Ashland/Mansfield, OH'
df5.loc[(df5['formatted_market'] == 'iHeart Media - NewYork, NY'),'formatted_market'] = 'iHeart Media - New York, NY'
df5.loc[(df5['formatted_market'] == 'iHeart Media - Modesto, CA'),'formatted_market'] = 'iHeart Media - Modesto/Stockton, CA'



# df5.formatted_market.unique()

df6 = pd.concat([df1,df5], axis=1)

df6 = df6.rename(columns = {'Opportunity: Opportunity ID': 'iHeart Opportunity ID',
                            'stage': 'Stage',
                           'market_division': 'market division',
                           'market_area': 'market area',
                            'market': 'market',
                           'ae_name': 'AE name',
                           'new_business': 'New or Existing Biz',
                           'account': 'iHeart AE\'s Account Name',
                           'opportunity': 'iHeart AE\'s Opportunity Name',
                           'project_id': 'project_id',
                           'form_date': 'Form Date',
                           'opportunity_created_date': 'opportunity_created_date',
                           'opportunity_closed_date': 'opportunity_closed_date',
                           'gross_expected_revenue': 'gross_expected_revenue',
                           'gross_amount': 'gross_amount',
                           'form_created_on_closed_opp': 'form_created_on_closed_opp',
                           'market_type': 'market_type',
                           'formatted_market': 'formatted_market'})

df6.drop('market', axis=1, inplace=True)

# df6.to_csv('rev_salesforce.csv', index = 0)

df6.shape
# Out:
# (13842, 17)

# %%
# db1.opportynity_id = [x[3:] for x in db1.opportynity_id]

# %%
inner_merge = pd.merge(df6,db1, on=['project_id', 'project_id'])
inner_merge
# Out:
#       iHeart Opportunity ID           Stage    market division  \
# 0           0060y00001BJfCT    Closed - Won                NaN
# 1           0060y00001EBeNY    Closed - Won  MidWest-SouthEast
# 2           0060y00001EBxnB    Closed - Won                NaN
# 3           0060y00001BIhNk   Closed - Lost                NaN
# 4           0060y00001ECIMf    Closed - Won                NaN
# ...                     ...             ...                ...
# 13505       0060y00001Fd86R  Proposal Built             Hopeck
# 13506       0060y00001FAxmC    Closed - Won             Hopeck
# 13507       0060y00001FcEz1  Proposal Built            LeGrett
# 13508       0060y00001FdBkM  Proposal Built             Hopeck
# 13509       0060y00001FcstW    Closed - Won             Hopeck
#
#            market area                      AE name New or Existing Biz  \
# 0                  NaN             Scott Schoenberg   Existing Business
# 1             North FL                  Marcus Cash   Existing Business
# 2                  NaN                Jordan Lemire   Existing Business
# 3                  NaN  Jennifer Minigutti Mayfield   Existing Business
# 4                  NaN  Jennifer Minigutti Mayfield   Existing Business
# ...                ...                          ...                 ...
# 13505          Rockies                    Deb Mager   Existing Business
# 13506            Miami           Brandi Yurgealitis   Existing Business
# 13507  Los Angeles, CA              Lindsay Hatcher   Existing Business
# 13508   Washington, DC                   Robin Horn   Existing Business
# 13509     Philadelphia           JODI PINCUS LOKOFF   Existing Business
#
#                     iHeart AE's Account Name  \
# 0                  Vita Coco/All Market Inc.
# 1                     Lineage Logistics, LLC
# 2                          The Juicy Seafood
# 3                            CHURCHILL DOWNS
# 4               American Furniture Warehouse
# ...                                      ...
# 13505                     OMEARA FORD CENTER
# 13506               Funky Buddha Brewery LLC
# 13507            Canoga Park Heating and Air
# 13508                  Zips Franchising, LLC
# 13509  College Hunks Hauling Junk and Moving
#
#                             iHeart AE's Opportunity Name   project_id  \
# 0      MMP-31480_VitaCoco_Tampa_Houston-Inside Sales-...  AVCPoABgAAA
# 1      Lineage Lo-Baltimore/DC Hiring-Inside Sales-83...  A5REIDFAAAA
# 2                     The Juicy -NA-Inside Sales-8388042  A7mgJKIwAAA
# 3            Churchill-iOS Launch in PA & IN-MMS-7520478  A5VAODFAAAA
# 4        AMERICAN F-Houston Test Market-MMS-Copy-8405929  A7ngJKIwAAA
# ...                                                  ...          ...
# 13505            O'Meara Service December Add-on-9107290  Bx8nuFBwAAA
# 13506                            Funky Buddha Q4-8933095  ByA-jGIAAAA
# 13507  Canoga Par-2021 Jan-Dec Campaign-Hatcher, Lind...  Bx-cAGIAAAA
# 13508  Zips Franc-ZIPS DRY CLEANERS - GOODBYE 2020-Ho...  ByBIoFGQAAA
# 13509  College Hunk IAC Influencer Campaign 2021 Annu...  Bx7wvGIAAAA
#
#                  Form Date opportunity_created_date opportunity_closed_date  \
# 0         3/4/2020 1:43 PM                12/6/2019               1/24/2020
# 1        6/22/2020 1:01 PM                6/16/2020               6/25/2020
# 2        6/29/2020 3:03 PM                6/19/2020               7/28/2020
# 3        6/22/2020 5:30 PM               11/25/2019               6/23/2020
# 4        6/29/2020 4:11 PM                6/24/2020               6/24/2020
# ...                    ...                      ...                     ...
# 13505  12/11/2020 11:22 AM               12/11/2020               1/10/2021
# 13506   12/11/2020 4:20 PM               10/26/2020              11/23/2020
# 13507   12/11/2020 1:26 PM               11/30/2020                1/8/2021
# 13508   12/11/2020 4:31 PM               12/11/2020              12/28/2020
# 13509  12/11/2020 10:24 AM                12/8/2020              12/11/2020
#
#        gross_expected_revenue  gross_amount  form_created_on_closed_opp  \
# 0                   147840.00     147840.00                           1
# 1                    51265.67      51265.67                           0
# 2                     2000.00       2000.00                           0
# 3                        0.00     522600.00                           0
# 4                    65195.00      65195.00                           1
# ...                       ...           ...                         ...
# 13505                 3143.00       8980.00                           0
# 13506                10230.00      10230.00                           1
# 13507                24000.00      48000.00                           0
# 13508                    0.00          0.00                           0
# 13509                30000.00      30000.00                           1
#
#       market_type                 formatted_market            create_ts  \
# 0             NaN      iHeart Media - Inside Sales  2020-03-04 14:43:36
# 1             NaN      iHeart Media - Inside Sales  2020-06-22 14:01:45
# 2             NaN      iHeart Media - Inside Sales  2020-06-29 16:03:22
# 3             NaN    iHeart Media - National Sales  2020-06-22 18:30:39
# 4             NaN    iHeart Media - National Sales  2020-06-29 17:11:38
# ...           ...                              ...                  ...
# 13505    Regional        iHeart Media - Denver, CO  2020-12-11 12:22:55
# 13506    Regional         iHeart Media - Miami, FL  2020-12-11 17:20:19
# 13507    Regional   iHeart Media - Los Angeles, CA  2020-12-11 14:26:57
# 13508    Regional    iHeart Media - Washington, DC  2020-12-11 17:31:05
# 13509    Regional  iHeart Media - Philadelphia, PA  2020-12-11 11:24:15
#
#                                    email                      name  \
# 0              grantadam@iheartmedia.com                Grant Adam
# 1             marcuscash@iheartmedia.com               Marcus Cash
# 2          kellyflanagan@iheartmedia.com  Kelly Christine Flanagan
# 3         JenniferBedard@iheartmedia.com           Jennifer Bedard
# 4               debmager@iheartmedia.com                 Deb Mager
# ...                                  ...                       ...
# 13505           debmager@iheartmedia.com                 Deb Mager
# 13506  BrandiYurgealitis@iheartmedia.com        Brandi Yurgealitis
# 13507     Lindsayhatcher@iheartmedia.com           Lindsay Hatcher
# 13508          RobinHorn@iheartmedia.com                Robin Horn
# 13509         JodiLokoff@iheartmedia.com               Jodi Lokoff
#
#                                    group  submissions      opportynity_id  \
# 0                        Los Angeles, CA           11  0060y00001BJfCTAA1
# 1      St. Petersburg, FL | Inside Sales            6  0060y00001EBeNYAA1
# 2                         Birmingham, AL            5  0060y00001EBxnBAAT
# 3                      New York City, NY            6  0060y00001BIhNkAAL
# 4                             Denver, CO            5  0060y00001ECIMfAAP
# ...                                  ...          ...                 ...
# 13505                         Denver, CO            5  0060y00001Fd86RAAR
# 13506                         Miami, FL             6  0060y00001FAxmCAAT
# 13507                    Los Angeles, CA            5  0060y00001FcEz1AAF
# 13508                     Washington, DC            5  0060y00001FdBkMAAV
# 13509                   Philadelphia, PA            5  0060y00001FcstWAAR
#
#        credits_used                                  industry  \
# 0               1.0  Retail/Computer,Electronics & Appliances
# 1               1.0                       Transportation Svcs
# 2               1.0                               Restaurants
# 3               1.0                                  Gambling
# 4               1.0                 Home Building/Improvement
# ...             ...                                       ...
# 13505           1.5                             Miscellaneous
# 13506           1.0                           Food & Beverage
# 13507           1.0                 Home Building/Improvement
# 13508           1.0                         Consumer Services
# 13509           1.0                       Transportation Svcs
#
#                                                     tone
# 0                                                  Funny
# 1                                                Serious
# 2                      I don't care as long as it's good
# 3                                                Serious
# 4                      I don't care as long as it's good
# ...                                                  ...
# 13505  No preference. I'm open to a range of good ideas.
# 13506  No preference. I'm open to a range of good ideas.
# 13507                                            Serious
# 13508                                              Funny
# 13509  No preference. I'm open to a range of good ideas.
#
# [13510 rows x 26 columns]

# %%
# inner_merge.opportynity_id = [x[:15] for x in inner_merge.opportynity_id]

# %%
inner_merge
# Out:
#       iHeart Opportunity ID           Stage    market division  \
# 0           0060y00001BJfCT    Closed - Won                NaN
# 1           0060y00001EBeNY    Closed - Won  MidWest-SouthEast
# 2           0060y00001EBxnB    Closed - Won                NaN
# 3           0060y00001BIhNk   Closed - Lost                NaN
# 4           0060y00001ECIMf    Closed - Won                NaN
# ...                     ...             ...                ...
# 13505       0060y00001Fd86R  Proposal Built             Hopeck
# 13506       0060y00001FAxmC    Closed - Won             Hopeck
# 13507       0060y00001FcEz1  Proposal Built            LeGrett
# 13508       0060y00001FdBkM  Proposal Built             Hopeck
# 13509       0060y00001FcstW    Closed - Won             Hopeck
#
#            market area                      AE name New or Existing Biz  \
# 0                  NaN             Scott Schoenberg   Existing Business
# 1             North FL                  Marcus Cash   Existing Business
# 2                  NaN                Jordan Lemire   Existing Business
# 3                  NaN  Jennifer Minigutti Mayfield   Existing Business
# 4                  NaN  Jennifer Minigutti Mayfield   Existing Business
# ...                ...                          ...                 ...
# 13505          Rockies                    Deb Mager   Existing Business
# 13506            Miami           Brandi Yurgealitis   Existing Business
# 13507  Los Angeles, CA              Lindsay Hatcher   Existing Business
# 13508   Washington, DC                   Robin Horn   Existing Business
# 13509     Philadelphia           JODI PINCUS LOKOFF   Existing Business
#
#                     iHeart AE's Account Name  \
# 0                  Vita Coco/All Market Inc.
# 1                     Lineage Logistics, LLC
# 2                          The Juicy Seafood
# 3                            CHURCHILL DOWNS
# 4               American Furniture Warehouse
# ...                                      ...
# 13505                     OMEARA FORD CENTER
# 13506               Funky Buddha Brewery LLC
# 13507            Canoga Park Heating and Air
# 13508                  Zips Franchising, LLC
# 13509  College Hunks Hauling Junk and Moving
#
#                             iHeart AE's Opportunity Name   project_id  \
# 0      MMP-31480_VitaCoco_Tampa_Houston-Inside Sales-...  AVCPoABgAAA
# 1      Lineage Lo-Baltimore/DC Hiring-Inside Sales-83...  A5REIDFAAAA
# 2                     The Juicy -NA-Inside Sales-8388042  A7mgJKIwAAA
# 3            Churchill-iOS Launch in PA & IN-MMS-7520478  A5VAODFAAAA
# 4        AMERICAN F-Houston Test Market-MMS-Copy-8405929  A7ngJKIwAAA
# ...                                                  ...          ...
# 13505            O'Meara Service December Add-on-9107290  Bx8nuFBwAAA
# 13506                            Funky Buddha Q4-8933095  ByA-jGIAAAA
# 13507  Canoga Par-2021 Jan-Dec Campaign-Hatcher, Lind...  Bx-cAGIAAAA
# 13508  Zips Franc-ZIPS DRY CLEANERS - GOODBYE 2020-Ho...  ByBIoFGQAAA
# 13509  College Hunk IAC Influencer Campaign 2021 Annu...  Bx7wvGIAAAA
#
#                  Form Date opportunity_created_date opportunity_closed_date  \
# 0         3/4/2020 1:43 PM                12/6/2019               1/24/2020
# 1        6/22/2020 1:01 PM                6/16/2020               6/25/2020
# 2        6/29/2020 3:03 PM                6/19/2020               7/28/2020
# 3        6/22/2020 5:30 PM               11/25/2019               6/23/2020
# 4        6/29/2020 4:11 PM                6/24/2020               6/24/2020
# ...                    ...                      ...                     ...
# 13505  12/11/2020 11:22 AM               12/11/2020               1/10/2021
# 13506   12/11/2020 4:20 PM               10/26/2020              11/23/2020
# 13507   12/11/2020 1:26 PM               11/30/2020                1/8/2021
# 13508   12/11/2020 4:31 PM               12/11/2020              12/28/2020
# 13509  12/11/2020 10:24 AM                12/8/2020              12/11/2020
#
#        gross_expected_revenue  gross_amount  form_created_on_closed_opp  \
# 0                   147840.00     147840.00                           1
# 1                    51265.67      51265.67                           0
# 2                     2000.00       2000.00                           0
# 3                        0.00     522600.00                           0
# 4                    65195.00      65195.00                           1
# ...                       ...           ...                         ...
# 13505                 3143.00       8980.00                           0
# 13506                10230.00      10230.00                           1
# 13507                24000.00      48000.00                           0
# 13508                    0.00          0.00                           0
# 13509                30000.00      30000.00                           1
#
#       market_type                 formatted_market            create_ts  \
# 0             NaN      iHeart Media - Inside Sales  2020-03-04 14:43:36
# 1             NaN      iHeart Media - Inside Sales  2020-06-22 14:01:45
# 2             NaN      iHeart Media - Inside Sales  2020-06-29 16:03:22
# 3             NaN    iHeart Media - National Sales  2020-06-22 18:30:39
# 4             NaN    iHeart Media - National Sales  2020-06-29 17:11:38
# ...           ...                              ...                  ...
# 13505    Regional        iHeart Media - Denver, CO  2020-12-11 12:22:55
# 13506    Regional         iHeart Media - Miami, FL  2020-12-11 17:20:19
# 13507    Regional   iHeart Media - Los Angeles, CA  2020-12-11 14:26:57
# 13508    Regional    iHeart Media - Washington, DC  2020-12-11 17:31:05
# 13509    Regional  iHeart Media - Philadelphia, PA  2020-12-11 11:24:15
#
#                                    email                      name  \
# 0              grantadam@iheartmedia.com                Grant Adam
# 1             marcuscash@iheartmedia.com               Marcus Cash
# 2          kellyflanagan@iheartmedia.com  Kelly Christine Flanagan
# 3         JenniferBedard@iheartmedia.com           Jennifer Bedard
# 4               debmager@iheartmedia.com                 Deb Mager
# ...                                  ...                       ...
# 13505           debmager@iheartmedia.com                 Deb Mager
# 13506  BrandiYurgealitis@iheartmedia.com        Brandi Yurgealitis
# 13507     Lindsayhatcher@iheartmedia.com           Lindsay Hatcher
# 13508          RobinHorn@iheartmedia.com                Robin Horn
# 13509         JodiLokoff@iheartmedia.com               Jodi Lokoff
#
#                                    group  submissions   opportynity_id  \
# 0                        Los Angeles, CA           11  0060y00001BJfCT
# 1      St. Petersburg, FL | Inside Sales            6  0060y00001EBeNY
# 2                         Birmingham, AL            5  0060y00001EBxnB
# 3                      New York City, NY            6  0060y00001BIhNk
# 4                             Denver, CO            5  0060y00001ECIMf
# ...                                  ...          ...              ...
# 13505                         Denver, CO            5  0060y00001Fd86R
# 13506                         Miami, FL             6  0060y00001FAxmC
# 13507                    Los Angeles, CA            5  0060y00001FcEz1
# 13508                     Washington, DC            5  0060y00001FdBkM
# 13509                   Philadelphia, PA            5  0060y00001FcstW
#
#        credits_used                                  industry  \
# 0               1.0  Retail/Computer,Electronics & Appliances
# 1               1.0                       Transportation Svcs
# 2               1.0                               Restaurants
# 3               1.0                                  Gambling
# 4               1.0                 Home Building/Improvement
# ...             ...                                       ...
# 13505           1.5                             Miscellaneous
# 13506           1.0                           Food & Beverage
# 13507           1.0                 Home Building/Improvement
# 13508           1.0                         Consumer Services
# 13509           1.0                       Transportation Svcs
#
#                                                     tone
# 0                                                  Funny
# 1                                                Serious
# 2                      I don't care as long as it's good
# 3                                                Serious
# 4                      I don't care as long as it's good
# ...                                                  ...
# 13505  No preference. I'm open to a range of good ideas.
# 13506  No preference. I'm open to a range of good ideas.
# 13507                                            Serious
# 13508                                              Funny
# 13509  No preference. I'm open to a range of good ideas.
#
# [13510 rows x 26 columns]

# %%
inner_merge.to_csv('sf_final_for_import.csv')

# %%
db1
