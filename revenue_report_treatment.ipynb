# %% [markdown]
# ### Merging Inside Salespeople List With Revenue Report
# ### Dropping Duplicates by 'Opportunity'
# ### Renaming Columns
# ### Reformatting Market Names
# ### Writing 2 Versions to Separate CSVs

# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
from itertools import chain
from collections import Counter 
import openpyxl
import csv
import xlrd
import sys
import re

# %%
df1 = pd.read_csv('report1604062171181.csv')
df1.reset_index(drop=True)
df2 = pd.read_csv('IHM_Inside Sales_New-Term-Transfer_08202020.csv')
df2.reset_index(drop=True)
# df1.head()
# display(HTML(df2.to_html()))
# display(HTML(df1.to_html()))
# Out:
#            Employee Name                               Email  End Date  \
# 0        Adrian Gillaspy      AdrianGillaspy@iheartmedia.com   8/28/18
# 1             Aimee Kemp           AimeeKemp@iheartmedia.com    7/5/17
# 2        Alena Schlenker      AlenaSchlenker@iheartmedia.com   7/20/18
# 3             Alex Lewis          AlexLewis3@iheartmedia.com       NaN
# 4      Alexandra Ferraro    alexandraferraro@iheartmedia.com   3/23/18
# ..                   ...                                 ...       ...
# 171     William Lipplett     WilliamLipplett@iheartmedia.com    6/5/17
# 172  William Radzilowsky  WilliamRadzilowsky@iheartmedia.com    7/1/20
# 173       Yineth Bolanos       YinethBolanos@iheartmedia.com       NaN
# 174      Zachary Pollack      ZacharyPollack@iheartmedia.com  12/29/17
# 175     Zackary Crawford     ZackaryCrawford@iheartmedia.com   7/27/20
#
#      Status              Type
# 0      Term  Support - Remove
# 1      Term             Sales
# 2      Term  Support - Remove
# 3    Active             Sales
# 4      Term             Sales
# ..      ...               ...
# 171    Term             Sales
# 172    Term  Support - Remove
# 173  Active             Sales
# 174    Term             Sales
# 175    Term             Sales
#
# [176 rows x 5 columns]

# %%
df1.shape
# Out:
# (10664, 16)

# %%
# 1. Remove 'Support - Remove' from main df
# 2. Rename Sales, 'Support - Keep'
print('unique sales types: '), print(df2['Type'].unique())
print('number of inside salespeople: '), print(len(df2['Employee Name']))
# Out:
# unique sales types:
# ['Support - Remove' 'Sales' 'Support - Keep']
# number of inside salespeople:
# 176
# (None, None)

# %%
df1.columns
# Out:
# Index(['Opportunity: Stage', 'Opportunity: Opportunity Owner: Market Division',
#        'Opportunity: Opportunity Owner: Market Area',
#        'Opportunity: Opportunity Owner: Home Operating Market',
#        'Opportunity: Opportunity Owner: Full Name', 'New Business',
#        'Opportunity: Account Name: Account Name',
#        'Opportunity: Opportunity Name', 'Adwire Project ID', 'Form Date',
#        'Opportunity: Created Date', 'Opportunity: Close Date',
#        'Opportunity: Gross Expected Revenue', 'Opportunity: Gross Amount',
#        'Form Created on Closed Opp',
#        'Opportunity: Opportunity Owner: Market Type'],
#       dtype='object')

# %%
list = []

# this nested loop creates list of matches between the names in df2 (inside salespeople)
# and names of salespeople in df1 (revenue report)
def inside_sales_matches():
    for row in df1['Opportunity: Opportunity Owner: Full Name']:
        for name in df2['Employee Name']:
            if row == name:
                list.append(row)

                
inside_sales_matches()

# Casts the list made above to a dataframe so that it can be counted, and because I believe the code
# below will only take another dataframe for comparison
inside_sales_presence = pd.DataFrame(list, columns=['Employee Name'])

# list of unique matches between df1 and df2
inside_sales_presence_unique = np.unique(inside_sales_presence)

# produces list of matches sorted by frequency (size)
count = inside_sales_presence.groupby(['Employee Name']).size().sort_values(ascending=False)

# locates values where salesperson name in df1 matches salesperson name in df2 (unique matches list) and
# then changes the "home operating market" to "Inside Sales"
df1.loc[df1['Opportunity: Opportunity Owner: Full Name'].isin(inside_sales_presence_unique),
        'Opportunity: Opportunity Owner: Home Operating Market'] = 'Inside Sales'

df1 = df1.rename(columns = {'Opportunity: Stage': 'stage',
                           'Opportunity: Opportunity Owner: Market Division': 'market_division',
                           'Opportunity: Opportunity Owner: Market Area': 'market_area',
                           'Opportunity: Opportunity Owner: Home Operating Market': 'market',
                           'Opportunity: Opportunity Owner: Full Name': 'ae_name',
                           'New Business': 'new_business',
                           'Opportunity: Account Name: Account Name': 'account',
                           'Opportunity: Opportunity Name': 'opportunity',
                           'Adwire Project ID': 'project_id',
                           'Form Date': 'form_date',
                           'Opportunity: Created Date': 'opportunity_created_date',
                           'Opportunity: Close Date': 'opportunity_closed_date',
                           'Opportunity: Gross Expected Revenue': 'gross_expected_revenue',
                           'Opportunity: Gross Amount': 'gross_amount',
                           'Form Created on Closed Opp': 'form_created_on_closed_opp',
                           'Opportunity: Opportunity Owner: Market Type': 'market_type'})

# %%
re.findall('[A-Z][a-z]*', df1.market)
df1['patterns'] = df1['market'].str.findall('[A-Z][a-z]*', df1['market'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-f6d31a2c4aac> in <module>
# ----> 1 re.findall('[A-Z][a-z]*', df1.market)
#       2 df1['patterns'] = df1['market'].str.findall('[A-Z][a-z]*', df1['market'])
#
# ~/opt/anaconda3/lib/python3.7/re.py in findall(pattern, string, flags)
#     221
#     222     Empty matches are included in the result."""
# --> 223     return _compile(pattern, flags).findall(string)
#     224
#     225 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
df3 = df1.drop_duplicates(subset =["opportunity"])

# %%
print(df3.shape, df1.shape)
# Out:
# (9265, 16) (10664, 16)

# %%
# writes new dataframes to separate CSVs, resets index to col = 0
df1.to_csv('103020_duplicates.csv', index = 0)
df3.to_csv('103020_no_duplicates.csv', index = 0)

# %% [markdown]
# ### Dataframe of No-Market AEs

# %%
# List of people without markets
no_market = df1[df1['market'].isnull()]
# display(HTML(df1.to_html()))

# %%
no_market_list = no_market.ae_name.to_list()
no_market_list = set(no_market_list)
no_market_df = pd.DataFrame(no_market_list, columns = ['name'])

# %%
no_market_df.to_csv('aes_no_market.csv', index=0)

# %%
display(HTML(df2.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Employee Name</th>
#       <th>Email</th>
#       <th>End Date</th>
#       <th>Status</th>
#       <th>Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adrian Gillaspy</td>
#       <td>AdrianGillaspy@iheartmedia.com</td>
#       <td>8/28/18</td>
#       <td>Term</td>
#       <td>Support - Remove</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Aimee Kemp</td>
#       <td>AimeeKemp@iheartmedia.com</td>
#       <td>7/5/17</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Alena Schlenker</td>
#       <td>AlenaSchlenker@iheartmedia.com</td>
#       <td>7/20/18</td>
#       <td>Term</td>
#       <td>Support - Remove</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Alex Lewis</td>
#       <td>AlexLewis3@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Alexandra Ferraro</td>
#       <td>alexandraferraro@iheartmedia.com</td>
#       <td>3/23/18</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Alexia Harger</td>
#       <td>AlexiaHarger@iheartmedia.com</td>
#       <td>6/27/18</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Allistair Gibson</td>
#       <td>AllistairGibson@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Amanda Hanusa</td>
#       <td>AmandaHanusa@iheartmedia.com</td>
#       <td>8/5/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Amanda Shannon</td>
#       <td>AmandaShannon@iheartmedia.com</td>
#       <td>5/14/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Amber Beilstein</td>
#       <td>AmberBeilstein@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Anaysia Smith</td>
#       <td>AnaysiaSmith@iheartmedia.com</td>
#       <td>5/31/18</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Andrew Arcangel</td>
#       <td>D.AndrewArcangel@iheartmedia.com</td>
#       <td>4/3/17</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Andrew Strathmann</td>
#       <td>AndrewStrathmann@iheartmedia.com</td>
#       <td>6/3/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Angeles Aguilar</td>
#       <td>AngelesAguilar@iheartmedia.com</td>
#       <td>8/8/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Anthony Greco</td>
#       <td>anthonygreco@iheartmedia.com</td>
#       <td>6/19/17</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Anthony Wilson</td>
#       <td>AnthonyWilson@iheartmedia.com</td>
#       <td>9/4/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Ashley Inzinga</td>
#       <td>AshleyInzinga@iheartmedia.com</td>
#       <td>9/2/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Ashley McCague</td>
#       <td>AshleyMcCague@iheartmedia.com</td>
#       <td>9/4/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Austin Roher</td>
#       <td>AustinRoher@iheartmedia.com</td>
#       <td>5/21/18</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Bernardo Ortega</td>
#       <td>BernardoOrtega@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Brandee Backus</td>
#       <td>BrandeeBackus@iheartmedia.com</td>
#       <td>9/24/18</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Brenda Berardo</td>
#       <td>BrendaBerardo@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Brett Frieman</td>
#       <td>BrettFrieman@iheartmedia.com</td>
#       <td>4/26/19</td>
#       <td>Term</td>
#       <td>Support - Remove</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Bruce Harris</td>
#       <td>BruceHarris@iheartmedia.com</td>
#       <td>3/28/19</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Chris Kasak</td>
#       <td>ChrisKasak@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Cassandra Beach</td>
#       <td>CassandraBeach@iheartmedia.com</td>
#       <td>7/26/19</td>
#       <td>Term</td>
#       <td>Support - Remove</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Chuck Deskins</td>
#       <td>CHUCKDESKINS@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Catherine Ha</td>
#       <td>CatherineHa@iheartmedia.com</td>
#       <td>7/24/17</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Chandler Harper</td>
#       <td>DavidHarper@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Charlie Hesser</td>
#       <td>CharlesHesser@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Jeffrey Croy</td>
#       <td>JeffreyCroy@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Christi Faulkner</td>
#       <td>ChristiFaulkner@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Support - Keep</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Christina Sovich</td>
#       <td>ChristinaSovich@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Christopher Dalbo</td>
#       <td>ChristopherDalbo@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Christopher Murray</td>
#       <td>ChristopherMurray@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Christopher Vitola</td>
#       <td>ChristopherVitola@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Matthew Loyd</td>
#       <td>MattLoyd@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Colin Angle</td>
#       <td>ColinAngle@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Collin Bush</td>
#       <td>CollinBush@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Cory Lucas</td>
#       <td>CoryLucas@iheartmedia.com</td>
#       <td>1/31/20</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Daniel Lane</td>
#       <td>DanielLane@iheartmedia.com</td>
#       <td>NaN</td>
#       <td>Active</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Daniel Sawyer</td>
#       <td>DanielSawyer@iheartmedia.com</td>
#       <td>1/21/20</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Cameron James</td>
#       <td>CameronJames@iheartmedia.com</td>
#       <td>7/1/20</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>Dave Purdy</td>
#       <td>DavePurdy@iheartmedia.com</td>
#       <td>4/2/18</td>
#       <td>Term</td>
#       <td>Sales</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>David Carto

# %%
d
